# %% [markdown]
# <div style="background-image: linear-gradient(to right, #4b4cff , #00d4ff); text-align: center; padding: 50px;">
#   <h1 style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; font-size: 48px; color: white; text-shadow: 2px 2px #4b4cff;">
#   Digits Recognition
#   </h1>
# </div>

# %% [markdown]
# <h2 style="color:#f7ce5b; font-family: Arial, sans-serif; font-size: 40px; margin-top: 50px; border-bottom: 2px solid #f7ce5b;">
# Library
# </h2>

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <h2 style="color:#f7ce5b; font-family: Arial, sans-serif; font-size: 40px; margin-top: 50px; border-bottom: 2px solid #f7ce5b;">
# Data
# </h2>

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %% [markdown]
# <h2 style="color:#f7ce5b; font-family: Arial, sans-serif; font-size: 40px; margin-top: 50px; border-bottom: 2px solid #f7ce5b;">
# Graphics
# </h2>

# %%
label_counts = train['label'].value_counts()

plt.bar(label_counts.index, label_counts.values)

plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Distribution of Labels')
plt.xticks(list(label_counts.index))

plt.show()

# %% [markdown]
# Almost equally distributed with 4000 appearance of each digits.

# %%
missing_values = train.isnull().sum()
missing_values
# Out:
# label       0
# pixel0      0
# pixel1      0
# pixel2      0
# pixel3      0
#            ..
# pixel779    0
# pixel780    0
# pixel781    0
# pixel782    0
# pixel783    0
# Length: 785, dtype: int64

# %%
images = train.iloc[:16, 1:].values.reshape(-1, 28, 28)

fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i], cmap='binary')
    ax.set_axis_off()
plt.tight_layout()
plt.show()
